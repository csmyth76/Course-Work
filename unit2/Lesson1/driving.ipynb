# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# plot aesthetics
sns.set_style("white")

# %%
df = pd.read_csv("bad-drivers.csv")

# %%
df.describe()
# Out:
#        Number of drivers involved in fatal collisions per billion miles  \
# count                                          51.000000
# mean                                           15.790196
# std                                             4.122002
# min                                             5.900000
# 25%                                            12.750000
# 50%                                            15.600000
# 75%                                            18.500000
# max                                            23.900000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# count                                          51.000000
# mean                                           31.725490
# std                                             9.633438
# min                                            13.000000
# 25%                                            23.000000
# 50%                                            34.000000
# 75%                                            38.000000
# max                                            54.000000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# count                                          51.000000
# mean                                           30.686275
# std                                             5.132213
# min                                            16.000000
# 25%                                            28.000000
# 50%                                            30.000000
# 75%                                            33.000000
# max                                            44.000000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted  \
# count                                          51.000000
# mean                                           85.921569
# std                                            15.158949
# min                                            10.000000
# 25%                                            83.000000
# 50%                                            88.000000
# 75%                                            95.000000
# max                                           100.000000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents  \
# count                                           51.00000
# mean                                            88.72549
# std                                              6.96011
# min                                             76.00000
# 25%                                             83.50000
# 50%                                             88.00000
# 75%                                             95.00000
# max                                            100.00000
#
#        Car Insurance Premiums ($)  \
# count                   51.000000
# mean                   886.957647
# std                    178.296285
# min                    641.960000
# 25%                    768.430000
# 50%                    858.970000
# 75%                   1007.945000
# max                   1301.520000
#
#        Losses incurred by insurance companies for collisions per insured driver ($)
# count                                          51.000000
# mean                                          134.493137
# std                                            24.835922
# min                                            82.750000
# 25%                                           114.645000
# 50%                                           136.050000
# 75%                                           151.870000
# max                                           194.780000

# %%
df.columns = ['state', 'drivers_num', 'speeding', 'alcohol', 'notDistracted', 'noPrevious', 'insurance', 'losses']

# %%
# does this need to be Idempotent
df.describe()
# Out:
#        drivers_num   speeding    alcohol  notDistracted  noPrevious  \
# count    51.000000  51.000000  51.000000      51.000000    51.00000
# mean     15.790196  31.725490  30.686275      85.921569    88.72549
# std       4.122002   9.633438   5.132213      15.158949     6.96011
# min       5.900000  13.000000  16.000000      10.000000    76.00000
# 25%      12.750000  23.000000  28.000000      83.000000    83.50000
# 50%      15.600000  34.000000  30.000000      88.000000    88.00000
# 75%      18.500000  38.000000  33.000000      95.000000    95.00000
# max      23.900000  54.000000  44.000000     100.000000   100.00000
#
#          insurance      losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
g = sns.PairGrid(df)

g = g.map(plt.scatter)

plt.show()

# %%
corrmat = df.corr()
print(corrmat)

# Set up the matplotlib figure.
f, ax = plt.subplots(figsize=(12, 9))

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
# Out:
#                drivers_num  speeding   alcohol  notDistracted  noPrevious  \
# drivers_num       1.000000 -0.029080  0.199426       0.009782   -0.017942
# speeding         -0.029080  1.000000  0.286244       0.131738    0.014066
# alcohol           0.199426  0.286244  1.000000       0.043380   -0.245455
# notDistracted     0.009782  0.131738  0.043380       1.000000   -0.195265
# noPrevious       -0.017942  0.014066 -0.245455      -0.195265    1.000000
# insurance        -0.199702  0.042541 -0.017451       0.019578    0.075533
# losses           -0.036011 -0.061241 -0.083916      -0.058467    0.042770
#
#                insurance    losses
# drivers_num    -0.199702 -0.036011
# speeding        0.042541 -0.061241
# alcohol        -0.017451 -0.083916
# notDistracted   0.019578 -0.058467
# noPrevious      0.075533  0.042770
# insurance       1.000000  0.623116
# losses          0.623116  1.000000

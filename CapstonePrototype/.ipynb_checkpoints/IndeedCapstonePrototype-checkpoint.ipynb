# %%
from bs4 import BeautifulSoup # For HTML parsing
import urllib.request # Website connections
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = urllib.request.urlopen(website).read() # Connect to the job posting
    except: 
        print('site not found')
        return   # Need this in case the website isn't there anymore or some other weird connection problem 
    
    soup_obj = BeautifulSoup(site, 'lxml') # Get the html from the site
    
    if len(soup_obj) == 0: # In case the default parser lxml doesn't work, try another one
        soup_obj = BeautifulSoup(site, 'html5lib')
    
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    
    text = soup_obj.get_text() # Get the text from this
    lines = (line.strip() for line in text.splitlines()) # break into lines
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    text = ''.join(chunk for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
    
    # Now clean out all of the unicode junk (this line works great!!!)
    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        print ('unable to decode')
        return                                                         # an exception
    
    # decode the bytes to string so that regex can be used
    text = text.decode('ISO-8859-1')
    text = re.sub("[^a-zA-Z+3]"," ", text)  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                             # Also include + for C++
    text = re.sub(r"([a-z])([A-Z])", r"\1 \2", text) # Fix spacing issue from merged words
    text = text.lower().split()  # Go to lower case and split them apart
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                           # or not on the website)
    return text

# %%
sample = text_cleaner('http://www.indeed.com/viewjob?jk=5505e59f8e5a32a4&q=%22data+scientist%22&tk=19ftfgsmj19ti0l3&from=web&advn=1855944161169178&sjdu=QwrRXKrqZ3CNX5W-O9jEvWC1RT2wMYkGnZrqGdrncbKqQ7uwTLXzT1_ME9WQ4M-7om7mrHAlvyJT8cA_14IV5w&pub=pub-indeed')
sample[:20] # Just show the first 20 words
# Out:
# ['programs',
#  'p',
#  'econometrics',
#  'searches',
#  'trading',
#  'bonus',
#  'behavior',
#  'learning',
#  'si',
#  'nlp',
#  'engineer',
#  'fitness',
#  'catered',
#  'waindeed',
#  'meals',
#  'per',
#  'keywords',
#  'vision',
#  'waamazon',
#  'commuter']

# %%
def skills_info(city = None, state = None):
    '''
    This function will take a desired city/state and look for all new job postings
    on Indeed.com. It will crawl all of the job postings and keep track of how many
    use a preset list of typical data science skills. The final percentage for each skill
    is then displayed at the end of the collation. 
    
    Inputs: The location's city and state. These are optional. If no city/state is input, 
    the function will assume a national search (this can take a while!!!).
    Input the city/state as strings, such as skills_info('Chicago', 'IL').
    Use a two letter abbreviation for the state.
    
    Output: A bar chart showing the most commonly desired skills in the job market for 
    a data scientist. 
    '''
    
    final_job = 'data+scientist' # searching for data scientist exact fit("data scientist" on Indeed search)
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
    if city is not None:
        final_city = city.split() 
        final_city = '+'.join(word for word in final_city)
        final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                   '%2C+', state] # Join all of our strings together so that indeed will search correctly
    else:
        final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

    final_site = ''.join(final_site_list) # Merge the html address together into one string
    base_url = 'http://www.indeed.com'

    try:
        html = urllib.request.urlopen(final_site).read() # Open up the front page of our search first
    except:
        'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
        return
    soup = BeautifulSoup(html, 'lxml') # Get the html from the first page

    # Now find out how many jobs there were
    num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
    
    num_jobs_area = num_jobs_area.decode('ISO-8859-1')# The 'searchCount' object has this
    
    job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result
    
    print('num_jobs_area'+ str(num_jobs_area))
    print('job_numbers' + str(job_numbers))
    
    if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
        total_num_jobs = (int(job_numbers[1])*1000) + int(job_numbers[3])
    else:
        total_num_jobs = int(job_numbers[1]) 
    
    city_title = city
    if city is None:
        city_title = 'Nationwide'
    print ('There were {} jobs found, {}'.format(total_num_jobs,city_title)) # Display how many jobs were found
    num_pages = total_num_jobs/10 # This will be how we know the number of times we need to iterate over each new
                                  # search result page
    job_descriptions = [] # Store all our descriptions in this list
    
    for i in xrange(1,num_pages+1): # Loop through all of our search result pages
        print ('Getting page '+ i)
        start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
        current_page = ''.join([final_site, '&start=', start_num])
        
        # Now that we can view the correct 10 job returns, start collecting the text samples from each
        html_page = urllib.request.urlopen(current_page).read() # Get the page
        page_obj = BeautifulSoup(html_page) # Locate all of the job links
        job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
        job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs
        job_URLS = filter(lambda x:'clk' in x, job_URLS) # Now get just the job related URLS
        
        for j in xrange(0,len(job_URLS)):
            final_description = text_cleaner(job_URLS[j])
            if final_description: # So that we only append when the website was accessed correctly
                job_descriptions.append(final_description)
            sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 
    
    print ('Done with collecting the job postings!')  
    print ('There were {} jobs successfully found.'.format(len(job_descriptions)))


    doc_frequency = Counter() # This will create a full counter of our terms. 
    [doc_frequency.update(item) for item in job_descriptions] # List comp

    # Now we can just look at our final dict list inside doc_frequency

    # Obtain our key terms and store them in a dict. These are the key data science skills we are looking for
    prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                    'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
                   'Ruby':doc_frequency['ruby'],
                  'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
                  'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})
                  
    analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                      'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                      'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

    hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
               'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
               'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
               'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
               'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})
               
    database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
                 'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
                 'MongoDB':doc_frequency['mongodb']})
                      
    overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
    final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
                                                                                                # dataframe 
    # Change the values to reflect a percentage of the postings 
    final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                                  #  having that term 
    # Sort the data for plotting purposes
    final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)

    # Get it ready for a bar plot
    final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
                              title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)
    
    final_plot.set_ylabel('Percentage Appearing in Job Ads')
    fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object
    
    
    return fig, final_frame # End of the function

# %%
seattle_info = skills_info(city = 'Seattle', state = 'WA')
# Out:
# num_jobs_area
#         Page 1 of 353 jobs
# job_numbers['1', '353']
# There were 353 jobs found, Seattle
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-7dda5b287c3e> in <module>()
# ----> 1 seattle_info = skills_info(city = 'Seattle', state = 'WA')
#
# <ipython-input-82-ac81c89107c9> in skills_info(city, state)
#      59     job_descriptions = [] # Store all our descriptions in this list
#      60
# ---> 61     for i in xrange(1,num_pages+1): # Loop through all of our search result pages
#      62         print ('Getting page '+ i)
#      63         start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
#
# NameError: name 'xrange' is not defined

# %%
city = 'Seattle'
state = 'WA'


final_job = 'data+scientist' # searching for data scientist exact fit("data scientist" on Indeed search)

# Make sure the city specified works properly if it has more than one word (such as San Francisco)
if city is not None:
    final_city = city.split() 
    final_city = '+'.join(word for word in final_city)
    final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
               '%2C+', state] # Join all of our strings together so that indeed will search correctly
else:
    final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

final_site = ''.join(final_site_list) # Merge the html address together into one string
base_url = 'http://www.indeed.com'

try:
    html = urllib.request.urlopen(final_site).read() # Open up the front page of our search first
except:
    'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
    
soup = BeautifulSoup(html, 'lxml') # Get the html from the first page

# Now find out how many jobs there were
num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found

num_jobs_area = num_jobs_area.decode('ISO-8859-1')# The 'searchCount' object has this

job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result

if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
    total_num_jobs = (int(job_numbers[1])*1000) + int(job_numbers[3])
else:
    total_num_jobs = int(job_numbers[1]) 

city_title = city
if city is None:
    city_title = 'Nationwide'
print ('There were {} jobs found, {}'.format(total_num_jobs,city_title)) # Display how many jobs were found
num_pages = int(total_num_jobs/10) # This will be how we know the number of times we need to iterate over each new
                              # search result page
job_descriptions = [] # Store all our descriptions in this list

for i in range(1,num_pages+1): # Loop through all of our search result pages
    print ('Getting page {}'.format(i))
    start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
    current_page = ''.join([final_site, '&start=', start_num])

    # Now that we can view the correct 10 job returns, start collecting the text samples from each
    html_page = urllib.request.urlopen(current_page).read() # Get the page
    page_obj = BeautifulSoup(html_page, 'lxml') # Locate all of the job links
    job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
    

    # Get the URLS for the jobs
    job_URLS=[]
    for link in job_link_area.find_all('a'):
        if link.get('href') == None:
            print('no href attribute')
            continue
        job_URLS.append(base_url + link.get('href'))
    job_URLS = list(filter(lambda x:'clk' in x, job_URLS)) # Now get just the job related URLS
 
    for j in range(0,len(job_URLS)):
        final_description = text_cleaner(job_URLS[j])
        if final_description: # So that we only append when the website was accessed correctly
            job_descriptions.append(final_description)
        sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 

print ('Done with collecting the job postings!')  
print ('There were {} jobs successfully found.'.format(len(job_descriptions)))


doc_frequency = Counter() # This will create a full counter of our terms. 
[doc_frequency.update(item) for item in job_descriptions] # List comp

# Now we can just look at our final dict list inside doc_frequency

# Obtain our key terms and store them in a dict. These are the key data science skills we are looking for
prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
               'Ruby':doc_frequency['ruby'],
              'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
              'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})

analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                  'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                  'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
           'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
           'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
           'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
           'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})

database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
             'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
             'MongoDB':doc_frequency['mongodb']})

overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
                                                                                            # dataframe 
# Change the values to reflect a percentage of the postings 
final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                              #  having that term 
# Sort the data for plotting purposes
final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)

# Get it ready for a bar plot
final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
                          title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)

final_plot.set_ylabel('Percentage Appearing in Job Ads')
fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object

doc_frequency = Counter() # This will create a full counter of our terms. 
[doc_frequency.update(item) for item in job_descriptions] # List comp

# Now we can just look at our final dict list inside doc_frequency

# Obtain our key terms and store them in a dict. These are the key data science skills we are looking for
prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
               'Ruby':doc_frequency['ruby'],
              'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
              'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})

analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                  'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                  'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
           'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
           'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
           'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
           'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})

database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
             'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
             'MongoDB':doc_frequency['mongodb']})
# Out:
# There were 351 jobs found, Seattle
# Getting page 1
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=528205c6b4db1ecf&fccid=21ba96632d29e921&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Leafly-Holdings-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Leafly-Holdings', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Leafly-Holdings.html', 'http://www.indeed.com/rc/clk?jk=3decb38d87a325d9&fccid=160efb82f2462f14&vjs=3', 'http://www.indeed.com/cmp/Expedia-Group', 'http://www.indeed.com/cmp/Expedia-Group/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Expedia-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Expedia-Group', 'http://www.indeed.com/cmp/Expedia-Group/faq', 'http://www.indeed.com/cmp/Expedia-Group/faq/is-this-job-must-be-performed-from-expedia-call-center-in-las-vegas-nv-or-it-can-be-done-at-person-s-home?quid=1aph9km111d1f3nn', 'http://www.indeed.com/cmp/Expedia-Group/faq/how-are-the-working-hours?quid=1ao76rnphak9gc68', 'http://www.indeed.com/forum/cmp/Expedia-Group.html', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/rc/clk?jk=df4f97a5009aa0b7&fccid=913e1b259c8d65e2&vjs=3', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Zillow-Group-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/faq', 'http://www.indeed.com/cmp/Zillow/faq/how-did-you-feel-about-telling-people-you-worked-at-zillow?quid=1bspm0n6n1ahj65j', 'http://www.indeed.com/cmp/Zillow/faq/what-is-the-vacation-policy-like-how-many-vacation-days-do-you-get-per-year?quid=1c4i9orobak5t9ou', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Zillow.html', 'http://www.indeed.com/company/Whizglobal/jobs/Data-Scientist-76cc64dd64c5acf0?fccid=e97fd78f5d61a6fe&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Whizglobal-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Redmond-WA', 'http://www.indeed.com/forum/cmp/Whizglobal-5.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=a8de65f998dd8364&fccid=d7bd935bd17bc575&vjs=3', 'http://www.indeed.com/cmp/Infoblox', 'http://www.indeed.com/cmp/Infoblox/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Infoblox-l-Tacoma,-WA-jobs.html', 'http://www.indeed.com/l-Tacoma,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Tacoma-WA', 'http://www.indeed.com/cmp/Infoblox', 'http://www.indeed.com/forum/loc/Tacoma-Washington.html', 'http://www.indeed.com/forum/cmp/Infoblox.html', 'http://www.indeed.com/rc/clk?jk=ff775ea47339f0ba&fccid=315baf4b0afa894b&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Bittrex-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/forum/cmp/Bittrex.html', 'http://www.indeed.com/rc/clk?jk=dd227bf9dc982386&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#',  ...
# Getting page 2
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=3ca70019708ef4e1&fccid=d4b58fa60b80adb8&vjs=3', 'http://www.indeed.com/cmp/Rover.com', 'http://www.indeed.com/cmp/Rover.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Rover-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Rover.com', 'http://www.indeed.com/cmp/Rover.com/faq', 'http://www.indeed.com/cmp/Rover.com/faq/do-you-get-paid-alot-if-so-how-much?quid=1av2pop1qakaaeai', 'http://www.indeed.com/cmp/Rover.com/faq/can-i-only-walk-dogs-sitting-is-an-issue-with-roommates-who-already-have-2-dogs?quid=1b03ig6o31bgf5hn', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=542d3a666a7572b8&fccid=a908e0bf9963fb01&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/jobs?q=Zume+Inc&l=Seattle,+WA&nc=jasx', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=b8c8286254f48c18&fccid=b983e0b562a36362&vjs=3', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Providence-Health-&-Services-l-Renton,-WA-jobs.html', 'http://www.indeed.com/l-Renton,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Renton-WA', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/why-did-you-leave-your-job-at-providence-health-services?quid=1bbn6ovioas118hk', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/what-questions-did-they-ask-during-your-interview?quid=1am9fr2tab80pco4', 'http://www.indeed.com/forum/loc/Renton-Washington.html', 'http://www.indeed.com/forum/cmp/Providence-Health-%26-Services.html', 'http://www.indeed.com/rc/clk?jk=beed7ca3e72af2b0&fccid=b83660b09952e10e&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/jobs?q=Quardev,+Inc&l=Seattle,+WA&nc=jasx', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=5e68760cad2ae3eb&fccid=b0157d60f7e532f6&vjs=3', 'http://www.indeed.com/cmp/Rei', 'http://www.indeed.com/cmp/Rei/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Rei-l-Kent,-WA-jobs.html', 'http://www.indeed.com/l-Kent,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Kent-WA', 'http://www.indeed.com/cmp/Rei', 'http://www.indeed.com/cmp/Rei/faq', 'http://www.indeed.com/cmp/Rei/faq/how-did-you-get-your-first-interview-at-rei?quid=1allke8cnb85af4i', 'http://www.indeed.com/cmp/Rei/faq/what-kind-of-attire-is-appropriate-for-group-interview?quid=1bn3kbj8ibrdaf49', 'http://www.indeed.com/forum/loc/Kent-Washington.html', 'http://www.indeed.com/forum/cmp/Rei.html', 'http://www.indeed.com/rc/clk?jk=805d0e08f18c879e&fccid=80ae396f81c04794&vjs=3', 'http://www.indeed.com/cmp/Concur', 'http://www.indeed.com/cmp/Concur/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Concur-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Concur', 'http://www.indeed.com/cmp/Concur/faq', 'http://www.indeed.com/cmp/Concur/faq/how-are-the-working-hours?qui ...
# Getting page 3
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=8524622e3739b931&fccid=f7b190e23d6955d7&vjs=3', 'http://www.indeed.com/cmp/Eagleview-Technologies', 'http://www.indeed.com/cmp/Eagleview-Technologies/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Eagleview-Technologies-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Eagleview-Technologies', 'http://www.indeed.com/cmp/Eagleview-Technologies/faq', 'http://www.indeed.com/cmp/Eagleview-Technologies/faq/how-did-you-feel-about-telling-people-you-worked-at-eagleview-technologies?quid=1bmn6nci6brcvf0f', 'http://www.indeed.com/cmp/Eagleview-Technologies/faq/what-is-the-most-stressful-part-about-working-at-eagleview-technologies?quid=1cl0qqe67b88ie3k', 'http://www.indeed.com/forum/cmp/Eagleview-Technologies.html', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/rc/clk?jk=a6a6ee6c3674214e&fccid=1639254ea84748b5&vjs=3', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Facebook-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/faq', 'http://www.indeed.com/cmp/Facebook/faq/can-you-work-from-home?quid=1bltlotduaqgjcq8', 'http://www.indeed.com/cmp/Facebook/faq/how-did-you-feel-about-telling-people-you-worked-at-facebook?quid=1b3c2eqhhakab996', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Facebook.html', 'http://www.indeed.com/rc/clk?jk=cc7e7134ffb81bae&fccid=cdb9423a6994f324&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Lab126-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Amazon-e4e34143.html', 'http://www.indeed.com/rc/clk?jk=139ebc9eed3ae08a&fccid=602d63cae1cb7d0b&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Suplari-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Suplari.html', 'http://www.indeed.com/rc/clk?jk=2255f445f791ff70&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com/addlLoc/redirect?tk=1cmtnsbkpaft4a78&jk=2255f445f791ff70&dest=%2Fjobs%3Fq%3D%2522data%2Bscientist%2522%26l%3DSeattle%252C%2BWA%26rbt%3DData%2B%2526%2BApplied%2BScientist%26rbc%3DMicrosoft%26jtid%3Dc8ff68734e2962e9%26jcid%3D734cb5a01ee60f80%26grp%3Dtcl', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/rc/clk?jk=1ccbcb8d3b673d05&fccid=f2c78a21989b6814&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#' ...
# Getting page 4
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=db5ec3d9e51dfc5d&fccid=1639254ea84748b5&vjs=3', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Facebook-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/faq', 'http://www.indeed.com/cmp/Facebook/faq/can-you-work-from-home?quid=1bltlotduaqgjcq8', 'http://www.indeed.com/cmp/Facebook/faq/how-did-you-feel-about-telling-people-you-worked-at-facebook?quid=1b3c2eqhhakab996', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Facebook.html', 'http://www.indeed.com/rc/clk?jk=2d4f323180cce9f5&fccid=4514e98bb41669d2&vjs=3', 'http://www.indeed.com/cmp/Convoy', 'http://www.indeed.com/cmp/Convoy/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Convoy-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Convoy', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Convoy.html', 'http://www.indeed.com/rc/clk?jk=d4c998adcc13638f&fccid=d6ef41e202aa2c0b&vjs=3', 'http://www.indeed.com/cmp/Indeed', 'http://www.indeed.com/cmp/Indeed/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Indeed-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Indeed', 'http://www.indeed.com/cmp/Indeed/faq', 'http://www.indeed.com/cmp/Indeed/faq/what-is-the-best-way-to-get-an-interview?quid=1aih8a744akagdj7', 'http://www.indeed.com/cmp/Indeed/faq/how-is-the-food-in-the-different-offices?quid=1ap55lo04b8bsdtb', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Indeed.html', 'http://www.indeed.com/company/Neal-Analytics/jobs/Data-Scientist-3a9e6d662a59e2e6?fccid=a3bcc3a125bee804&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Neal-Analytics-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Redmond-WA', 'http://www.indeed.com/forum/cmp/Neal-Analytics.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=8fc2bb9aea118159&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Amazon-Com-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/faq', 'http://www.indeed.com/cmp/Amazon.com/faq/what-would-you-suggest-amazon-com-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bb857n98brch8lj', 'http://www.indeed.com/cmp/Amazon.com/faq/if-you-were-to-leave-amazon-com-what-would-be-the-reason?quid=1bb9r3ilcakgj8dv', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=3252960c328965f5&fccid=d4b58fa60b80adb8&vjs=3', 'http://www.indeed.com/cmp/Rover.com', 'http://www.indeed.com/cmp/Rover.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Rover-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www ...
# Getting page 5
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=4dc6be702673bc7f&fccid=913e1b259c8d65e2&vjs=3', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Zillow-Group-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/faq', 'http://www.indeed.com/cmp/Zillow/faq/how-did-you-feel-about-telling-people-you-worked-at-zillow?quid=1bspm0n6n1ahj65j', 'http://www.indeed.com/cmp/Zillow/faq/what-is-the-vacation-policy-like-how-many-vacation-days-do-you-get-per-year?quid=1c4i9orobak5t9ou', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Zillow.html', 'http://www.indeed.com/rc/clk?jk=8f1885cb99406b91&fccid=28be5add96e32e66&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Inabia-Solutions-Consulting-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Redmond-WA', 'http://www.indeed.com/forum/cmp/Inabia-Solutions-and-Consulting.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=0dbd2c5303a7b9e3&fccid=1639254ea84748b5&vjs=3', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Facebook-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/faq', 'http://www.indeed.com/cmp/Facebook/faq/can-you-work-from-home?quid=1bltlotduaqgjcq8', 'http://www.indeed.com/cmp/Facebook/faq/how-did-you-feel-about-telling-people-you-worked-at-facebook?quid=1b3c2eqhhakab996', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Facebook.html', 'http://www.indeed.com/rc/clk?jk=2ff647ed1599cc65&fccid=af76a8783f0afba1&vjs=3', 'http://www.indeed.com/cmp/Smartsheet', 'http://www.indeed.com/cmp/Smartsheet/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Smartsheet-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Smartsheet', 'http://www.indeed.com/cmp/Smartsheet/faq', 'http://www.indeed.com/cmp/Smartsheet/faq/what-advice-would-you-give-the-ceo-of-smartsheet-about-how-to-improve-it?quid=1aub845b7aqhd8en', 'http://www.indeed.com/cmp/Smartsheet/faq/how-do-you-feel-about-going-to-work-each-day?quid=1c4it12lpb89rfj9', 'http://www.indeed.com/forum/cmp/Smartsheet.html', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/rc/clk?jk=1d979685917c68a3&fccid=a5b4499d9e91a5c6&vjs=3', 'http://www.indeed.com/cmp/Google', 'http://www.indeed.com/cmp/Google/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Google-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Google', 'http://www.indeed.com/cmp/Google/faq', 'http://www.indeed.com/cmp/Google/faq/what-type-of-education-qualification-is-needed-for-getting-good-job-in-google-company?quid=1al29f9bv1d070eg', 'http://www.indeed.com/cmp/Google/faq/can-i-work-from-home-for-google?quid=1c2doofca5ncqe5i', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Google.html', 'http://www.indeed.com/rc/clk?jk=eb3b4fca8834100c&fccid=4ffdd90de5b0ef8f& ...
# Getting page 6
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=5aab9e4f27dbbfc7&fccid=7b7d74f58f990cb9&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/jobs?q=Mercedes-benz+Research+%26+Development+North+America,+Inc&l=Seattle,+WA&nc=jasx', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Mercedes--benz-Research-&-Development-North-America,-Inc.', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/company/ifusioncore/jobs/Senior-Data-Scientist-b725b782aea56162?fccid=cd437007d27dd2e9&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Ifusioncore-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Redmond-WA', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/forum/cmp/Ifusioncore.html', 'http://www.indeed.com/rc/clk?jk=b3992bc9d308db62&fccid=1639254ea84748b5&vjs=3', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Facebook-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Facebook', 'http://www.indeed.com/cmp/Facebook/faq', 'http://www.indeed.com/cmp/Facebook/faq/can-you-work-from-home?quid=1bltlotduaqgjcq8', 'http://www.indeed.com/cmp/Facebook/faq/how-did-you-feel-about-telling-people-you-worked-at-facebook?quid=1b3c2eqhhakab996', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Facebook.html', 'http://www.indeed.com/rc/clk?jk=bde34f8d264381e3&fccid=b95f9eb47968fa13&vjs=3', 'http://www.indeed.com/cmp/Boston-Consulting-Group', 'http://www.indeed.com/cmp/Boston-Consulting-Group/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-The-Boston-Consulting-Group-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Boston-Consulting-Group', 'http://www.indeed.com/cmp/Boston-Consulting-Group/faq', 'http://www.indeed.com/cmp/Boston-Consulting-Group/faq/what-benefits-does-the-company-provide?quid=1as33vptk52t49mm', 'http://www.indeed.com/cmp/Boston-Consulting-Group/faq/how-often-do-raises-occur-at-boston-consulting-group?quid=1bd0t84apakhdd25', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Boston-Consulting-Group.html', 'http://www.indeed.com/rc/clk?jk=c6337c6b2982c952&fccid=d7bd935bd17bc575&vjs=3', 'http://www.indeed.com/cmp/Infoblox', 'http://www.indeed.com/cmp/Infoblox/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Infoblox-l-Tacoma,-WA-jobs.html', 'http://www.indeed.com/l-Tacoma,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Tacoma-WA', 'http://www.indeed.com/cmp/Infoblox', 'http://www.indeed.com/forum/loc/Tacoma-Washington.html', 'http://www.indeed.com/forum/cmp/Infoblox.html', 'http://www.indeed.com/rc/clk?jk=d1cfec758f3d2b65&fccid=0f50160682a8ab27&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/jobs?q=Liveperson+-+Global+Product+%26+Technology&l=Seattle,+WA&nc=jasx', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Liveperson---Global-Product-%26-Technology.html', 'http://www.indeed.com/rc/clk?jk=8d6cabe4c5ab2f4c&fccid=fe2d21eef233e94a&vjs=3', ...
# Getting page 7
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=509fc76a20e8f63c&fccid=c68f858ef73a0c44&vjs=3', 'http://www.indeed.com/cmp/Getty-Images', 'http://www.indeed.com/cmp/Getty-Images/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Getty-Images-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Computer-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Getty-Images', 'http://www.indeed.com/cmp/Getty-Images/faq', 'http://www.indeed.com/cmp/Getty-Images/faq/how-do-you-feel-about-the-future-of-getty-images?quid=1av0bmpto5j62dpa', 'http://www.indeed.com/cmp/Getty-Images/faq/how-long-does-it-take-to-get-hired-from-start-to-finish-what-are-the-steps-along-the-way?quid=1c6st20nqb8b7ekt', 'http://www.indeed.com/forum/cmp/Getty-Images.html', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=3854d5f4ef6e3149&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Amazon-Com-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/faq', 'http://www.indeed.com/cmp/Amazon.com/faq/what-would-you-suggest-amazon-com-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bb857n98brch8lj', 'http://www.indeed.com/cmp/Amazon.com/faq/if-you-were-to-leave-amazon-com-what-would-be-the-reason?quid=1bb9r3ilcakgj8dv', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=ec93065dfa5d8aff&fccid=38fd7bd102c4d12e&vjs=3', 'http://www.indeed.com/cmp/Big-Fish-Games', 'http://www.indeed.com/cmp/Big-Fish-Games/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Big-Fish-Games-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Big-Fish-Games', 'http://www.indeed.com/cmp/Big-Fish-Games/faq', 'http://www.indeed.com/cmp/Big-Fish-Games/faq/if-you-were-to-leave-big-fish-games-what-would-be-the-reason?quid=1bbugpqfubrd8a8b', 'http://www.indeed.com/cmp/Big-Fish-Games/faq/what-would-you-suggest-big-fish-games-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bbugpqg3b85f8ol', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Big-Fish-Games.html', 'http://www.indeed.com/rc/clk?jk=76fa32dd975aa261&fccid=5527fa86119a4ea6&vjs=3', 'http://www.indeed.com/cmp/The-Climate-Corporation', 'http://www.indeed.com/cmp/The-Climate-Corporation/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/jobs?q=The+Climate+Corporation&l=Seattle,+WA&nc=jasx', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Researcher-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/The-Climate-Corporation', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/The-Climate-Corporation.html', 'http://www.indeed.com/rc/clk?jk=a1bcb42b1b64c945&fccid=913e1b259c8d65e2&vjs=3', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Zillow-Group-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/faq', 'http://www.indeed.com/cmp/Zillow/faq/how-did-you-feel-about-telling-people-you-worked-at-zillow?quid=1b ...
# Getting page 8
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=1ad7029ac623a233&fccid=c2c6a7536e4d9df3&vjs=3', 'http://www.indeed.com/cmp/Paccar-Inc.', 'http://www.indeed.com/cmp/Paccar-Inc./reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Paccar-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Paccar-Inc.', 'http://www.indeed.com/cmp/Paccar-Inc./faq', 'http://www.indeed.com/cmp/Paccar-Inc./faq/what-is-the-sick-leave-policy-like-how-many-sick-days-do-you-get-per-year?quid=1b0a15fbvaqisbnt', 'http://www.indeed.com/cmp/Paccar-Inc./faq/what-is-the-vacation-policy-like-how-many-vacation-days-do-you-get-per-year?quid=1bdkga494b86cfer', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/rc/clk?jk=32280e769e0684d1&fccid=4514e98bb41669d2&vjs=3', 'http://www.indeed.com/cmp/Convoy', 'http://www.indeed.com/cmp/Convoy/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Convoy-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Convoy', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Convoy.html', 'http://www.indeed.com/rc/clk?jk=03d0187b8fed4a74&fccid=edae4285faf6c2f0&vjs=3', 'http://www.indeed.com/cmp/Boeing', 'http://www.indeed.com/cmp/Boeing/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Boeing-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Boeing', 'http://www.indeed.com/cmp/Boeing/faq', 'http://www.indeed.com/cmp/Boeing/faq/what-is-the-interview-process-like?quid=1ac7h1n75ak8qe5c', 'http://www.indeed.com/cmp/Boeing/faq/why-did-you-leave-your-job-at-boeing?quid=1bbrq5qadbrcravr', 'http://www.indeed.com/forum/cmp/Boeing.html', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/rc/clk?jk=019dc8d3adb5c7c2&fccid=913e1b259c8d65e2&vjs=3', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Zillow-Group-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Zillow', 'http://www.indeed.com/cmp/Zillow/faq', 'http://www.indeed.com/cmp/Zillow/faq/how-did-you-feel-about-telling-people-you-worked-at-zillow?quid=1bspm0n6n1ahj65j', 'http://www.indeed.com/cmp/Zillow/faq/what-is-the-vacation-policy-like-how-many-vacation-days-do-you-get-per-year?quid=1c4i9orobak5t9ou', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Zillow.html', 'http://www.indeed.com/rc/clk?jk=6dc81edfd5d39d7a&fccid=8ee7a0e69adb9e08&vjs=3', 'http://www.indeed.com/cmp/Porch', 'http://www.indeed.com/cmp/Porch/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Porch-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Porch', 'http://www.indeed.com/cmp/Porch/faq', 'http://www.indeed.com/cmp/Porch/faq/how-long-does-it-take-to-get-hired-from-start-to-finish-what-are-the-steps-along-the-way?quid=1aqflpbgsakajcnd', 'http://www.indeed.com/cmp/Porch/faq/why-did-you-leave-your-job-at-porch?quid=1bbm2g7beb811f9f', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Porch.html', 'http://www.indeed.com/company/Conation-Consulting ...
# Getting page 9
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=6abd17f1f1fd05b8&fccid=160efb82f2462f14&vjs=3', 'http://www.indeed.com/cmp/Expedia-Group', 'http://www.indeed.com/cmp/Expedia-Group/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Expedia-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Expedia-Group', 'http://www.indeed.com/cmp/Expedia-Group/faq', 'http://www.indeed.com/cmp/Expedia-Group/faq/is-this-job-must-be-performed-from-expedia-call-center-in-las-vegas-nv-or-it-can-be-done-at-person-s-home?quid=1aph9km111d1f3nn', 'http://www.indeed.com/cmp/Expedia-Group/faq/how-are-the-working-hours?quid=1ao76rnphak9gc68', 'http://www.indeed.com/forum/cmp/Expedia-Group.html', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/rc/clk?jk=c490eb1dfe586ecf&fccid=3a71a4d2f7990a25&vjs=3', 'http://www.indeed.com/cmp/Allstate-Insurance', 'http://www.indeed.com/cmp/Allstate-Insurance/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Allstate-l-Bothell,-WA-jobs.html', 'http://www.indeed.com/l-Bothell,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bothell-WA', 'http://www.indeed.com/cmp/Allstate-Insurance', 'http://www.indeed.com/cmp/Allstate-Insurance/faq', 'http://www.indeed.com/cmp/Allstate-Insurance/faq/what-would-you-suggest-allstate-insurance-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bbh7uucgakgs9db', 'http://www.indeed.com/cmp/Allstate-Insurance/faq/how-are-the-working-hours?quid=1accqt5n3ak7j8ba', 'http://www.indeed.com/forum/loc/Bothell-Washington.html', 'http://www.indeed.com/forum/cmp/Allstate-Insurance.html', 'http://www.indeed.com/rc/clk?jk=3298ecacbe104dbd&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Amazon-Com-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/faq', 'http://www.indeed.com/cmp/Amazon.com/faq/what-would-you-suggest-amazon-com-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bb857n98brch8lj', 'http://www.indeed.com/cmp/Amazon.com/faq/if-you-were-to-leave-amazon-com-what-would-be-the-reason?quid=1bb9r3ilcakgj8dv', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=e37ec3911b0edfac&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Customer-Success-Manager-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=968aae52ce8662c0&fccid=d73294b71d7f0354&vjs=3', 'http://www.indeed.com/cmp/Ipsos', 'http://www.indeed.com/cmp/Ipsos/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Ipsos-North-America-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Market-Researcher-Salaries,-Seattle-WA', 'http://www.indeed.co ...
# Getting page 10
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=545db25e0a246c52&fccid=a3bcc3a125bee804&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Neal-Analytics-l-Kirkland,-WA-jobs.html', 'http://www.indeed.com/l-Kirkland,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Kirkland-WA', 'http://www.indeed.com/forum/loc/Kirkland-Washington.html', 'http://www.indeed.com/forum/cmp/Neal-Analytics.html', 'http://www.indeed.com/rc/clk?jk=c261efe94f3c8250&fccid=d4b58fa60b80adb8&vjs=3', 'http://www.indeed.com/cmp/Rover.com', 'http://www.indeed.com/cmp/Rover.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Rover-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Rover.com', 'http://www.indeed.com/cmp/Rover.com/faq', 'http://www.indeed.com/cmp/Rover.com/faq/do-you-get-paid-alot-if-so-how-much?quid=1av2pop1qakaaeai', 'http://www.indeed.com/cmp/Rover.com/faq/can-i-only-walk-dogs-sitting-is-an-issue-with-roommates-who-already-have-2-dogs?quid=1b03ig6o31bgf5hn', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=30a223c81360ff4e&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Amazon-Com-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Economist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/faq', 'http://www.indeed.com/cmp/Amazon.com/faq/what-would-you-suggest-amazon-com-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bb857n98brch8lj', 'http://www.indeed.com/cmp/Amazon.com/faq/if-you-were-to-leave-amazon-com-what-would-be-the-reason?quid=1bb9r3ilcakgj8dv', 'http://www.indeed.com/forum/job/Economist.html', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=41436a8f06596a4e&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Amazon-Com-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/faq', 'http://www.indeed.com/cmp/Amazon.com/faq/what-would-you-suggest-amazon-com-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bb857n98brch8lj', 'http://www.indeed.com/cmp/Amazon.com/faq/if-you-were-to-leave-amazon-com-what-would-be-the-reason?quid=1bb9r3ilcakgj8dv', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=7bfd4c0f7053e077&fccid=b8100d49050171d6&vjs=3', 'http://www.indeed.com/cmp/3coast', 'http://www.indeed.com/cmp/3coast/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-3coast-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/3coast', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/forum/cmp/3coast.html', 'http://www.indeed.com/rc/clk?jk=e6e9f02e2d012bf0&fccid=a5b4499d9e91a5c6&vjs=3', 'http://www.indeed.com/cmp/Google', 'http://www.indeed.com/cmp/Google/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Google-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salari ...
# Getting page 11
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=0f3ec69fc186090f&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com/addlLoc/redirect?tk=1cmto16r3a2hd85u&jk=0f3ec69fc186090f&dest=%2Fjobs%3Fq%3D%2522data%2Bscientist%2522%26l%3DSeattle%252C%2BWA%26rbt%3DPrincipal%2BData%2BScientist%26rbc%3DMicrosoft%26jtid%3D78de47969d749e3c%26jcid%3D734cb5a01ee60f80%26grp%3Dtcl', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Scientist-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=69a0632f17a21d2c&fccid=fe2d21eef233e94a&vjs=3', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Amazon-Com-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Data-Engineer-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Amazon.com', 'http://www.indeed.com/cmp/Amazon.com/faq', 'http://www.indeed.com/cmp/Amazon.com/faq/what-would-you-suggest-amazon-com-management-do-to-prevent-others-from-leaving-for-this-reason?quid=1bb857n98brch8lj', 'http://www.indeed.com/cmp/Amazon.com/faq/if-you-were-to-leave-amazon-com-what-would-be-the-reason?quid=1bb9r3ilcakgj8dv', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/rc/clk?jk=6ae8e75c840d5ca0&fccid=d8be85d73018fac8&vjs=3', 'http://www.indeed.com/cmp/Huawei', 'http://www.indeed.com/cmp/Huawei/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Huawei-l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/l-Bellevue,-WA-jobs.html', 'http://www.indeed.com/salaries/Senior-Staff-Scientist-Salaries,-Bellevue-WA', 'http://www.indeed.com/cmp/Huawei', 'http://www.indeed.com/cmp/Huawei/faq', 'http://www.indeed.com/cmp/Huawei/faq/how-are-the-working-hours?quid=1amigq7so5n8n80f', 'http://www.indeed.com/cmp/Huawei/faq/what-is-the-most-stressful-part-about-working-at-huawei-technologies-co-ltd?quid=1b8km7sdqak8sbg7', 'http://www.indeed.com/forum/loc/Bellevue-Washington.html', 'http://www.indeed.com/forum/cmp/Huawei.html', 'http://www.indeed.com/rc/clk?jk=10632ad8322bf189&fccid=2dd390c3a48a7ed0&vjs=3', 'http://www.indeed.com/cmp/Kpmg', 'http://www.indeed.com/cmp/Kpmg/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Kpmg-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Senior-Associate-Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Kpmg', 'http://www.indeed.com/cmp/Kpmg/faq', 'http://www.indeed.com/cmp/Kpmg/faq/why-did-you-leave-your-job-at-kpmg?quid=1bc4d8gkt5j52cqu', 'http://www.indeed.com/cmp/Kpmg/faq/what-is-the-work-environment-and-culture-like-at-kpmg-auditores-independentes?quid=1b6c94u5k5ncua0p', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Kpmg.html', 'http://www.indeed.com/rc/clk?jk=9b6649ef61ccf68b&fccid=cdb9423a6994f324&vjs=3', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Lab126-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Scientist-Salaries,-Seattle-WA', 'http://www.indeed.com/forum ...
# Getting page 12
# no href attribute
# ...
# Getting page 33
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=dfc516d70d38e593&fccid=b983e0b562a36362&vjs=3', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/reviews', 'http://www.indeed.com/addlLoc/redirect?tk=1cmtoe99t187i5s4&jk=dfc516d70d38e593&dest=%2Fjobs%3Fq%3D%2522data%2Bscientist%2522%26l%3DSeattle%252C%2BWA%26rbt%3DSenior%2BManager%252C%2BProduct%2BManagement%2BPSJH%26rbc%3DProvidence%2BHealth%2B%2526%2BServices%26jtid%3D54af0e4177a1a1d6%26jcid%3Db983e0b562a36362%26grp%3Dtcl', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Providence-Health-&-Services-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Senior-Director-of-Product-Management-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/why-did-you-leave-your-job-at-providence-health-services?quid=1bbn6ovioas118hk', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/what-questions-did-they-ask-during-your-interview?quid=1am9fr2tab80pco4', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Providence-Health-%26-Services.html', 'http://www.indeed.com/rc/clk?jk=ca3830712ee2de15&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Software-Engineer-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/job/Principal-Software-Engineer.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=3932f29eb9b4fcc5&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Engineering-Lead-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=9c369a077ab57a2b&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Software-Engineering-Manager-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=03fd5c5671511246&fccid=fe2d21eef233e94a&vjs=3', 'ht ...
# Getting page 34
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=dfc516d70d38e593&fccid=b983e0b562a36362&vjs=3', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/reviews', 'http://www.indeed.com/addlLoc/redirect?tk=1cmtoet9g1bt76th&jk=dfc516d70d38e593&dest=%2Fjobs%3Fq%3D%2522data%2Bscientist%2522%26l%3DSeattle%252C%2BWA%26rbt%3DSenior%2BManager%252C%2BProduct%2BManagement%2BPSJH%26rbc%3DProvidence%2BHealth%2B%2526%2BServices%26jtid%3D54af0e4177a1a1d6%26jcid%3Db983e0b562a36362%26grp%3Dtcl', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Providence-Health-&-Services-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Senior-Director-of-Product-Management-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/why-did-you-leave-your-job-at-providence-health-services?quid=1bbn6ovioas118hk', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/what-questions-did-they-ask-during-your-interview?quid=1am9fr2tab80pco4', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Providence-Health-%26-Services.html', 'http://www.indeed.com/rc/clk?jk=ca3830712ee2de15&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Software-Engineer-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/job/Principal-Software-Engineer.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=3932f29eb9b4fcc5&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Engineering-Lead-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=9c369a077ab57a2b&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Software-Engineering-Manager-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=03fd5c5671511246&fccid=fe2d21eef233e94a&vjs=3', 'ht ...
# Getting page 35
# no href attribute
# ['http://www.indeed.com/promo/prime', 'http://www.indeed.com/rc/clk?jk=dfc516d70d38e593&fccid=b983e0b562a36362&vjs=3', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/reviews', 'http://www.indeed.com/addlLoc/redirect?tk=1cmtofio718jj66t&jk=dfc516d70d38e593&dest=%2Fjobs%3Fq%3D%2522data%2Bscientist%2522%26l%3DSeattle%252C%2BWA%26rbt%3DSenior%2BManager%252C%2BProduct%2BManagement%2BPSJH%26rbc%3DProvidence%2BHealth%2B%2526%2BServices%26jtid%3D54af0e4177a1a1d6%26jcid%3Db983e0b562a36362%26grp%3Dtcl', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Providence-Health-&-Services-l-Seattle,-WA-jobs.html', 'http://www.indeed.com/l-Seattle,-WA-jobs.html', 'http://www.indeed.com/salaries/Senior-Director-of-Product-Management-Salaries,-Seattle-WA', 'http://www.indeed.com/cmp/Providence-Health-&-Services', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/why-did-you-leave-your-job-at-providence-health-services?quid=1bbn6ovioas118hk', 'http://www.indeed.com/cmp/Providence-Health-&-Services/faq/what-questions-did-they-ask-during-your-interview?quid=1am9fr2tab80pco4', 'http://www.indeed.com/forum/loc/Seattle-Washington.html', 'http://www.indeed.com/forum/cmp/Providence-Health-%26-Services.html', 'http://www.indeed.com/rc/clk?jk=ca3830712ee2de15&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Software-Engineer-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/job/Principal-Software-Engineer.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=3932f29eb9b4fcc5&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Engineering-Lead-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=9c369a077ab57a2b&fccid=734cb5a01ee60f80&vjs=3', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/reviews', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com#', 'http://www.indeed.com/q-Microsoft-l-Redmond,-WA-jobs.html', 'http://www.indeed.com/l-Redmond,-WA-jobs.html', 'http://www.indeed.com/salaries/Principal-Software-Engineering-Manager-Salaries,-Redmond-WA', 'http://www.indeed.com/cmp/Microsoft', 'http://www.indeed.com/cmp/Microsoft/faq', 'http://www.indeed.com/cmp/Microsoft/faq/how-are-the-working-hours?quid=1an36f47hb822853', 'http://www.indeed.com/cmp/Microsoft/faq/how-should-dress-for-an-interview?quid=1aoai61q1b8bd82f', 'http://www.indeed.com/forum/cmp/Microsoft.html', 'http://www.indeed.com/forum/loc/Redmond-Washington.html', 'http://www.indeed.com/rc/clk?jk=03fd5c5671511246&fccid=fe2d21eef233e94a&vjs=3', 'ht ...
# Done with collecting the job postings!
# There were 335 jobs successfully found.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-c673c03af4db> in <module>()
#     102
#     103 overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
# --> 104 final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a
#     105                                                                                             # dataframe
#     106 # Change the values to reflect a percentage of the postings
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     352                                          copy=False)
#     353             else:
# --> 354                 raise ValueError('DataFrame constructor not properly called!')
#     355
#     356         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
overall_total_skills.items()
# Out:
# dict_items([('R', 149), ('Python', 226), ('Java', 147), ('C++', 55), ('Ruby', 42), ('Perl', 31), ('Matlab', 27), ('JavaScript', 1), ('Scala', 66), ('Excel', 39), ('Tableau', 35), ('SAS', 50), ('SPSS', 23), ('D3', 12), ('Hadoop', 120), ('Spark', 121), ('Pig', 28), ('Hive', 86), ('Oozie', 1), ('Mahout', 15), ('SQL', 128), ('HBase', 10), ('Cassandra', 3)])

# %%
overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
                                                                                            # dataframe 
# Change the values to reflect a percentage of the postings 
final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                              #  having that term 
# Sort the data for plotting purposes
final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)

# Get it ready for a bar plot
final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
                          title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)

final_plot.set_ylabel('Percentage Appearing in Job Ads')
fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-a92e24416f10> in <module>()
#      26
#      27 overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
# ---> 28 final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a
#      29                                                                                             # dataframe
#      30 # Change the values to reflect a percentage of the postings
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     352                                          copy=False)
#     353             else:
# --> 354                 raise ValueError('DataFrame constructor not properly called!')
#     355
#     356         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
#overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
pd.DataFrame.from_dict(overall_total_skills,orient='index', columns=['Term', 'NumPostings']) # Convert these terms to a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-80b6aabb21f4> in <module>()
#       1 #overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
# ----> 2 pd.DataFrame.from_dict(overall_total_skills,orient='index', columns=['Term', 'NumPostings']) # Convert these terms to a
#       3
#
# TypeError: from_dict() got an unexpected keyword argument 'columns'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.20.3'
